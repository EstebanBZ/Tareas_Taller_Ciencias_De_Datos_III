# %% [markdown]
#   <h1>Tarea 04: Matplotlib & Seaborn</h1>

# %% [markdown]
# <font size='4'>Completar las siguientes tareas:</font>
#
# <hr style="height:2px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# Importar las siguientes librerías: `matplotlib.pyplot, seaborn, pandas, numpy`

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## <b>Recrea la siguiente figura</b>

# %%
# Generar valores de x en el rango deseado
x = np.linspace(-4, 4, 52)

# Calcular valores para curvas
y1 = 3 * np.exp(-0.25 * x**2)
y2 = 2.8 * np.exp(-0.15 * (x - 0.1)**2)

# Graficar curvas
plt.plot(x, y1, color='red', linestyle='-.', linewidth=2, label='3e^(-0.25x^2)')
plt.plot(x, y2, color='cyan', marker='o', markerfacecolor='yellow', markeredgecolor='black', markersize=6, linestyle='-', linewidth=2, label='2.8e^(-0.15(x-0.1)^2)')

# Configurar etiquetas y título del gráfico
plt.xlabel("That took a wile", fontweight='bold')
plt.title('Many Plots', fontweight='bold')
plt.legend(loc='upper right')

# Crear gráfico más pequeño en el centro
# Coordenadas del gráfico central
plt.axes([0.41, 0.18, 0.2, 0.3])
plt.text(-1.5, 2, "Cool", color='red')
plt.text(-0.5, 0, "Plot", color='blue')
plt.text(1, -2, "Bro", color='green')

plt.title('Small Plot')
plt.xlim(-2, 2)
plt.ylim(-3, 3)
plt.xticks(np.arange(-2, 2.5, 1))
plt.yticks(np.arange(-3, 3.5, 1))

plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
#   <hr style="height:3px;border:none;color:#333;background-color:#333;" />
#
#  <font size='4'> Para el resto de los ejercicios se deb usar el dataset Airbnb contenido en el archivo Airbnb.xlsx.</font>
#
# <h4> <b> Lee y guarda el dataset como `abnb`</b>

# %%
# Leer el archivo Excel
abnb = pd.read_excel('Airbnb.xlsx')

# %% [markdown]
# ## <b>Revisa el head de los datos:</b>

# %%
# Mostrar los datos
abnb.head(5)
# Out:
#    Unnamed: 0 neighbourhood_group       neighbourhood        room_type  price  \
# 0       33941              Queens           Ridgewood  Entire home/apt    280
# 1       21257           Manhattan    Theater District     Private room    195
# 2       23462            Brooklyn            Bushwick     Private room     65
# 3       29123            Brooklyn  Bedford-Stuyvesant  Entire home/apt    126
# 4       16774           Manhattan      Hell's Kitchen  Entire home/apt    199
#
#    minimum_nights  number_of_reviews last_review
# 0               2                 40  2019-06-24
# 1               1                  9  2018-12-16
# 2               5                 20  2019-04-21
# 3               1                  9  2018-03-02
# 4              30                  4  2018-03-31

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo la tabla desaparecerá.

# %% [markdown]
# ## <b> Recrea el siguiente `jointplot` </b>

# %%
# Generar el joinplot
sns.jointplot(data=abnb, x='number_of_reviews', y='price', kind='kde', fill=True, cmap='Blues')
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
# ## <b> Recrea los siguientes `boxplots` </b>

# %%
# Graficar boxplots
plt.figure(figsize=(8.4, 4.2))
sns.boxplot(data=abnb, x='neighbourhood_group', y='price')
plt.xlabel('Neighbourhood Group')
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %%
plt.figure(figsize=(8.4, 4.2))

sns.set(style="ticks")

# Graficar boxplots
sns.boxplot(data=abnb, x='neighbourhood_group', y='number_of_reviews', hue='room_type')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Reviews')
plt.ylim(-20, 370)

# Mostrar el gráfico
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
# ## <b> Recrea el siguiente  `violinplot` comparando la distribución de  `Entire home/apt` y `Private room` para los 5 `neighbourhood groups`</b>

# %%
# Filtrar los datos para las categorías de interés (Entire home/apt y Private room)
filtered_abnb = abnb.loc[abnb['room_type'].isin(['Entire home/apt', 'Private room'])]
sns.set(style="ticks")

# Ajustar tamaño de la figura
plt.figure(figsize=(10, 6))
# Graficar violinplot
sns.violinplot(data=filtered_abnb, x='neighbourhood_group', y='price', hue='room_type', split=True)

# Establecer etiquetas
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')

plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.

# %% [markdown]
# ## <b>Time Series: Recrea el siguiente gráfico</b>
#
# (Pista: Convierte la columna `last_review` a formato `DateTime`)

# %%
# Convertir la columna "last-review" al formato DateTime
abnb['last_review'] = pd.to_datetime(abnb['last_review'])
abnb_timepo = abnb[(abnb['last_review'] >= pd.to_datetime('2016-10-01')) & (abnb['last_review'] < pd.to_datetime('2019-03-01'))]

sns.set(style="ticks")

# Ajustar tamaño de la figura
plt.figure(figsize=(10, 6))

sns.lineplot(data=abnb_timepo, x='last_review', y='number_of_reviews', label='Number of Reviews')
sns.lineplot(data=abnb_timepo, x='last_review', y='price', label='Price')

plt.xlabel('last_review')
plt.ylabel('')
plt.title('Fluctutations in Number of Reviews and Price over time')

plt.legend()
plt.show()

# %%
#No ejecutar este módulo hasta que estés content@ con tu resultado. Al ejecutar el módulo el gráfico desaparecerá.
